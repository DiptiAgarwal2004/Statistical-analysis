# %%
import pandas as pd
import numpy as np
np.random.seed(42)

eye_colors = ['Blue', 'Green', 'Brown', 'Hazel']
genders = ['Male', 'Female']
marital_statuses = ['Single', 'Married', 'Divorced']
num_rows = 250

data = {
    'Eye Color': np.random.choice(eye_colors, num_rows),
    'Gender': np.random.choice(genders, num_rows),
    'Marital Status': np.random.choice(marital_statuses, num_rows),
    'Age Group': np.random.choice(['18-25', '26-35', '36-45', '46-55', '56+'], num_rows),
    'Income Level': np.random.choice(['Low', 'Medium', 'High'], num_rows)
}

df = pd.DataFrame(data)

df_counts = df.value_counts().reset_index(name='Count')

df_counts.to_csv('large_chi_square_dataset.csv', index=False)

print("Larger dataset with 5 columns and 250 rows saved as 'large_chi_square_dataset.csv':")
print(df_counts)
# Out:
# Larger dataset with 5 columns and 250 rows saved as 'large_chi_square_dataset.csv':
#     Eye Color  Gender Marital Status Age Group Income Level  Count
# 0       Green  Female         Single       56+       Medium      4
# 1       Brown    Male        Married     46-55          Low      3
# 2       Green  Female        Married     36-45         High      3
# 3       Brown  Female         Single     26-35         High      3
# 4       Brown    Male       Divorced     46-55          Low      3
# ..        ...     ...            ...       ...          ...    ...
# 178     Brown    Male       Divorced     26-35         High      1
# 179     Brown    Male       Divorced     26-35       Medium      1
# 180     Brown    Male       Divorced     36-45         High      1
# 181     Brown    Male       Divorced     46-55       Medium      1
# 182     Hazel    Male         Single       56+       Medium      1
#
# [183 rows x 6 columns]

# %%
import pandas as pd
from scipy.stats import chisquare, chi2_contingency
import itertools

df_counts = pd.read_csv('Dataset.csv')

print("Dataset Loaded:")
print(df_counts)

def chi_square_gof(column_name):
    observed_counts = df_counts.groupby(column_name)['Count'].sum()
    total_counts = observed_counts.sum()
    num_categories = len(observed_counts)
    expected_counts = [total_counts / num_categories] * num_categories
    chi2_stat, p_value = chisquare(observed_counts, expected_counts)
    df = num_categories - 1
    conclusion = "Reject the null hypothesis." if p_value < 0.05 else "Fail to reject the null hypothesis."
    return {
        'Chi-Squared Statistic': chi2_stat,
        'p-value': p_value,
        'Degrees of Freedom': df,
        'Conclusion': conclusion
    }

columns_to_test = ['Eye Color', 'Gender', 'Marital Status', 'Age Group', 'Income Level']
results_gof = {}

for col in columns_to_test:
    results_gof[col] = chi_square_gof(col)

for col, result in results_gof.items():
    print(f"\nChi-Square Goodness of Fit Test for {col}:")
    print(f"Chi-Squared Statistic: {result['Chi-Squared Statistic']}")
    print(f"p-value: {result['p-value']}")
    print(f"Degrees of Freedom: {result['Degrees of Freedom']}")
    print(f"Conclusion: {result['Conclusion']}")

def chi_square_independence(col1, col2):
    contingency_table = pd.crosstab(df_counts[col1], df_counts[col2], values=df_counts['Count'], aggfunc='sum').fillna(0)
    chi2_stat, p_value, dof, expected = chi2_contingency(contingency_table)
    conclusion = "Reject the null hypothesis." if p_value < 0.05 else "Fail to reject the null hypothesis."
    return {
        'Chi-Squared Statistic': chi2_stat,
        'p-value': p_value,
        'Degrees of Freedom': dof,
        'Conclusion': conclusion,
        'Expected Frequencies': expected
    }

results_independence = {}
column_pairs = list(itertools.combinations(columns_to_test, 2))

for col1, col2 in column_pairs:
    results_independence[(col1, col2)] = chi_square_independence(col1, col2)

for (col1, col2), result in results_independence.items():
    print(f"\nChi-Square Test of Independence between {col1} and {col2}:")
    print(f"Chi-Squared Statistic: {result['Chi-Squared Statistic']}")
    print(f"p-value: {result['p-value']}")
    print(f"Degrees of Freedom: {result['Degrees of Freedom']}")
    print(f"Conclusion: {result['Conclusion']}")
    print("Expected Frequencies:")
    print(result['Expected Frequencies'])
# Out:
# Dataset Loaded:
#     Eye Color  Gender Marital Status Age Group Income Level  Count
# 0       Green  Female         Single       56+       Medium      4
# 1       Brown    Male        Married     46-55          Low      3
# 2       Green  Female        Married     36-45         High      3
# 3       Brown  Female         Single     26-35         High      3
# 4       Brown    Male       Divorced     46-55          Low      3
# ..        ...     ...            ...       ...          ...    ...
# 178     Brown    Male       Divorced     26-35         High      1
# 179     Brown    Male       Divorced     26-35       Medium      1
# 180     Brown    Male       Divorced     36-45         High      1
# 181     Brown    Male       Divorced     46-55       Medium      1
# 182     Hazel    Male         Single       56+       Medium      1
#
# [183 rows x 6 columns]
#
# Chi-Square Goodness of Fit Test for Eye Color:
# Chi-Squared Statistic: 1.6800000000000002
# p-value: 0.6413893691403016
# Degrees of Freedom: 3
# Conclusion: Fail to reject the null hypothesis.
#
# Chi-Square Goodness of Fit Test for Gender:
# Chi-Squared Statistic: 0.784
# p-value: 0.37592058254807437
# Degrees of Freedom: 1
# Conclusion: Fail to reject the null hypothesis.
#
# Chi-Square Goodness of Fit Test for Marital Status:
# Chi-Squared Statistic: 1.544
# p-value: 0.4620879675837001
# Degrees of Freedom: 2
# Conclusion: Fail to reject the null hypothesis.
#
# Chi-Square Goodness of Fit Test for Age Group:
# Chi-Squared Statistic: 4.6
# p-value: 0.3308541842852522
# Degrees of Freedom: 4
# Conclusion: Fail to reject the null hypothesis.
#
# Chi-Square Goodness of Fit Test for Income Level:
# Chi-Squared Statistic: 0.34400000000000003
# p-value: 0.8419791731684998
# Degrees of Freedom: 2
# Conclusion: Fail to reject the null hypothesis.
#
# Chi-Square Test of Independence between Eye Color and Gender:
# Chi-Squared Statistic: 0.5669106039127868
# p-value: 0.9039638548210053
# Degrees of Freedom: 3
# Conclusion: Fail to reject the null hypothesis.
# Expected Frequencies:
# [[31.152 27.848]
#  [35.376 31.624]
#  [29.568 26.432]
#  [35.904 32.096]]
#
# Chi-Square Test of Independence between Eye Color and Marital Status:
# Chi-Squared Statistic: 3.0909621797891167
# p-value: 0.797346607430919
# Degrees of Freedom: 6
# Conclusion: Fail to reject the null hypothesis.
# Expected Frequencies:
# [[17.7   19.824 21.476]
#  [20.1   22.512 24.388]
#  [16.8   18.816 20.384]
#  [20.4   22.848 24.752]]
#
# Chi-Square Test of Independence between Eye Color and Age Group:
# Chi-Squared Statistic: 9.129125797931273
# p-value: 0.6918635917796487
# Degrees of Freedom: 12
# Conclusion: Fail to reject the null hypothesis.
# Expected Frequencies:
# [[11.8   12.508 10.384  9.912 14.396]
#  [13.4   14.204 11.792 11.256 16.348]
#  [11.2   11.872  9.856  9.408 13.664]
#  [13.6   14.416 11.968 11.424 16.592]]
#
# Chi-Square Test of Independence between Eye Color and Income Level:
# Chi-Squared Statistic: 10.48498947666622
# p-value: 0.10565837611341078
# Degrees of Freedom: 6
# Conclusion: Fail to reject the null hypothesis.
# Expected Frequencies:
# [[20.296 18.644 20.06 ]
#  [23.048 21.172 22.78 ]
#  [19.264 17.696 19.04 ]
#  [23.392 21.488 23.12 ]]
#
# Chi-Square Test of Independence between Gender and Marital Status:
# Chi-Squared Statistic: 0.7518376162443958
# p-value: 0.6866580818381681
# Degrees of Freedom: 2
# Conclusion: Fail to reject the null hypothesis.
# Expected Frequencies:
# [[39.6   44.352 48.048]
#  [35.4   39.648 42.952]]
#
# Chi-Square Test of Independence between Gender and Age Group:
# Chi-Squared Statistic: 8.399414677034853
# p-value: 0.07799543375815973
# Degrees of Freedom: 4
# Conclusion: Fail to reject the null hypothesis.
# Expected Frequencies:
# [[26.4   27.984 23.232 22.176 32.208]
#  [23.6   25.016 20.768 19.824 28.792]]
#
# Chi-Square Test of Independence between Gender and Income Level:
# Chi-Squared Statistic: 0.7008972813942362
# p-value: 0.7043720088715588
# Degrees of Freedom: 2
# Conclusion: Fail to reject the null hypothesis.
# Expected Frequencies:
# [[45.408 41.712 44.88 ]
#  [40.592 37.288 40.12 ]]
#
# Chi-Square Test of Independence between Marital Status and Age Group:
# Chi-Squared Statistic: 5.993385460787477
# p-value: 0.6479728549927117
# Degrees of Freedom: 8
# Conclusion: Fail to reject the null hypothesis.
# Expected Frequencies:
# [[15.    15.9   13.2   12.6   18.3  ]
#  [16.8   17.808 14.784 14.112 20.496]
#  [18.2   19.292 16.016 15.288 22.204]]
#
# Chi-Square Test of Independence between Marital Status and Income Level:
# Chi-Squared Statistic: 4.4362180731988
# p-value: 0.3501775017282244
# Degrees of Freedom: 4
# Conclusion: Fail to reject the null hypothesis.
# Expected Frequencies:
# [[25.8   23.7   25.5  ]
#  [28.896 26.544 28.56 ]
#  [31.304 28.756 30.94 ]]
#
# Chi-Square Test of Independence between Age Group and Income Level:
# Chi-Squared Statistic: 7.43554253177337
# p-value: 0.4904502942415305
# Degrees of Freedom: 8
# Conclusion: Fail to reject the null hypothesis.
# Expected Frequencies:
# [[17.2   15.8   17.   ]
#  [18.232 16.748 18.02 ]
#  [15.136 13.904 14.96 ]
#  [14.448 13.272 14.28 ]
#  [20.984 19.276 20.74 ]]
